# %%
# multiplication table
for i in range(1,13):
    print('******************************')
    for j in range(1, 13):
        print('when {} multiplied by {} gives {}'.format(i, j, i*j))
# Out:
# ******************************
# when 1 multiplied by 1 gives 1
# when 1 multiplied by 2 gives 2
# when 1 multiplied by 3 gives 3
# when 1 multiplied by 4 gives 4
# when 1 multiplied by 5 gives 5
# when 1 multiplied by 6 gives 6
# when 1 multiplied by 7 gives 7
# when 1 multiplied by 8 gives 8
# when 1 multiplied by 9 gives 9
# when 1 multiplied by 10 gives 10
# when 1 multiplied by 11 gives 11
# when 1 multiplied by 12 gives 12
# ******************************
# when 2 multiplied by 1 gives 2
# when 2 multiplied by 2 gives 4
# when 2 multiplied by 3 gives 6
# when 2 multiplied by 4 gives 8
# when 2 multiplied by 5 gives 10
# when 2 multiplied by 6 gives 12
# when 2 multiplied by 7 gives 14
# when 2 multiplied by 8 gives 16
# when 2 multiplied by 9 gives 18
# when 2 multiplied by 10 gives 20
# when 2 multiplied by 11 gives 22
# when 2 multiplied by 12 gives 24
# ******************************
# when 3 multiplied by 1 gives 3
# when 3 multiplied by 2 gives 6
# ...
